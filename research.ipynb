# %%
import google.generativeai as genai

# %%
GEMINI_API_KEY = "AIzaSyCYVLZ5mmo7yQ7fv4-yZusnbYay119eaxM"
genai.configure(api_key=GEMINI_API_KEY)

model = genai.GenerativeModel("gemini-2.5-flash")

# %%
user_input = "what is python"
prompt = f"Answer the provided question in short,Question:{user_input}"
response = model.generate_content(user_input)
print(response.text)
# Out:
# **Python is a high-level, general-purpose, interpreted programming language.**
#
# In simpler terms, it's a set of instructions and rules that a computer can understand to perform tasks. It's designed to be very readable and easy to use, making it popular for beginners and experienced developers alike.
#
# Here's a breakdown of what that means and why it's so popular:
#
# 1.  **High-level:**
#     *   You don't have to worry about low-level details like memory management or how the computer's CPU works. Python handles much of that complexity for you.
#     *   Its syntax is closer to human language (English) than to machine code, making it easier to read and write.
#
# 2.  **General-purpose:**
#     *   This means it's not specialized for one type of application. You can use Python for a vast array of tasks and in many different domains.
#
# 3.  **Interpreted:**
#     *   When you run a Python program, the code is executed directly by an interpreter line by line, without needing a separate compilation step (like C++ or Java). This speeds up the development process.
#
# 4.  **Created by Guido van Rossum:**
#     *   Python was first released in 1991 by Guido van Rossum.
#
# ---
#
# ### Key Characteristics & Philosophy:
#
# *   **Readability:** Python emphasizes code readability with its clear, uncluttered syntax and its use of indentation to define code blocks (instead of curly braces). This is often summarized by "The Zen of Python."
# *   **Simple to Learn:** Its straightforward syntax makes it an excellent language for beginners to pick up.
# *   **Object-Oriented:** It supports object-oriented programming (OOP) paradigms, allowing you to organize your code into reusable modules and components.
# *   **Dynamically Typed:** You don't have to declare the type of a variable (e.g., integer, string) explicitly; Python figures it out at runtime.
# *   **Large Standard Library & Ecosystem:** Python comes with a vast collection of modules and packages that provide pre-written code for common tasks, significantly speeding up development. Beyond the standard library, there's a massive third-party ecosystem (e.g., NumPy, Pandas, Django, Flask, TensorFlow).
# *   **Portability:** Python code can run on various operating systems (Windows, macOS, Linux, etc.) with minimal or no changes.
# *   **Open Source:** It's free to use and distribute.
#
# ---
#
# ### What is Python Used For? (Examples of its Versatility):
#
# *   **Web Development:** Building websites and web applications (e.g., using frameworks like Django and Flask).
# *   **Data Science & Machine Learning:** Analyzing data, building AI models, predictive analytics (e.g., libraries like NumPy, Pandas, Scikit-learn, TensorFlow, PyTorch).
# *   **Automation & Scripting:** Automating repetitive tasks, writing system administration scripts.
# *   **Game Development:** Creating games (e.g., using Pygame).
# *   **Desktop GUI Applications:** Building graphical user interfaces for desktop apps (e.g., using Tkinter, PyQt).
# *   **Scientific and Numeric Computing:** For research and complex calculations.
# *   **Education:** Widely used as a first programming language due to its simplicity.
# *   **DevOps:** For infrastructure as code, CI/CD pipelines.
#
# ---
#
# ### Simple Code Example:
#
# Here's what a "Hello, World!" program looks like in Python:
#
# ```python
# print("Hello, World!")
# ```
#
# And a slightly more complex example:
#
# ```python
# # This is a comment
# name = "Alice"
# age = 30
# message = f"Hello, {name}! You are {age} years old."
#
# print(message)
#
# if age >= 18:
#     print("You are an adult.")
# else:
#     print("You are a minor.")
# ```
#
# ---
#
# In essence, Python is a powerful, flexible, and approachable programming language that has found its way into almost every corner of the tech world, from small scripts to complex artificial intelligence systems.
